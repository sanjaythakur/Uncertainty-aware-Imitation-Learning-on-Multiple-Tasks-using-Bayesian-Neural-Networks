# %%
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use('ggplot')

from Plots import BBBvsGP_generalization, compare_conservativeness_with_scatter_plot, summarize_mujoco_runs, zoom_into_every_step, compare_data_efficiency

import sys
sys.path.insert(0,'./../')
from Housekeeping import *

# %%
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] = (3,5)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('axes', labelsize=18)

all_configurations = [
    {'controller': 'BBB' , 'detector_c': 7.0, 'detector_m': 200, 'number_demonstrations': 10},
    {'controller': 'NAIVE', 'number_demonstrations': 10},
]

compare_data_efficiency(domain_name='HalfCheetah',
                        all_configurations=all_configurations,
                        simulation_iterators=[0],
                        demonstration_request_to_gauge=2)
# Out:
# No handles with labels found to put in legend.

# %%
plt.rcParams["figure.figsize"] = (3,5)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('axes', labelsize=18)

all_configurations = [
    {'controller': 'BBB' , 'detector_c': 20.0, 'detector_m': 200, 'number_demonstrations': 10},
    {'controller': 'NAIVE', 'number_demonstrations': 10},
]

compare_data_efficiency(domain_name='Swimmer',
                        all_configurations=all_configurations,
                        simulation_iterators=[0],
                        demonstration_request_to_gauge=2)
# Out:
# No handles with labels found to put in legend.

# %%
plt.rcParams["figure.figsize"] = (10, 6)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('axes', labelsize=18)


zoom_into_every_step(domain_name='HalfCheetah',
                     number_demonstrations=10,
                     detector_c=7.0,
                     detector_m=200,
                     experiment_type='active_learning_proof_of_concept',
                     demonstration_request_to_gauge=1,
                     simulation_iterator=0,
                     validation_task_to_plot=[8, 3, 7])
# Out:
# Adaptive thresholds are [0.09007057, 0.15958421]
# Tasks trained on already are [8, 7]
# Tasks encountered so far are [8, 3, 7]
# Training tasks iterations so far are [0, 2]

# %%
plt.rcParams["figure.figsize"] = (10, 6)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('axes', labelsize=18)


zoom_into_every_step(domain_name='HalfCheetah',
                     number_demonstrations=10,
                     detector_c=7.0,
                     detector_m=200,
                     experiment_type='active_learning_proof_of_concept',
                     demonstration_request_to_gauge=2,
                     simulation_iterator=0,
                     validation_task_to_plot=[8, 3, 7])
# Out:
# Adaptive thresholds are [0.09007057, 0.15958421]
# Tasks trained on already are [8, 7]
# Tasks encountered so far are [8, 3, 7]
# Training tasks iterations so far are [0, 2]

# %%
plt.rcParams["figure.figsize"] = (10, 6)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('axes', labelsize=18)

zoom_into_every_step(domain_name='Swimmer',
                     number_demonstrations=10,
                     detector_c=20.0,
                     detector_m=200,
                     experiment_type='active_learning_proof_of_concept',
                     demonstration_request_to_gauge=1,
                     simulation_iterator=0,
                     validation_task_to_plot=[3,4,0])
# Out:
# Adaptive thresholds are [0.14768697, 0.11247996]
# Tasks trained on already are [3, 0]
# Tasks encountered so far are [3, 4, 0]
# Training tasks iterations so far are [0, 2]

# %%
plt.rcParams["figure.figsize"] = (10, 6)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('axes', labelsize=18)


zoom_into_every_step(domain_name='Swimmer',
                     number_demonstrations=10,
                     detector_c=20.0,
                     detector_m=200,
                     experiment_type='active_learning_proof_of_concept',
                     demonstration_request_to_gauge=2,
                     simulation_iterator=0,
                     validation_task_to_plot=[3,4,0])
# Out:
# Adaptive thresholds are [0.14768697, 0.11247996]
# Tasks trained on already are [3, 0]
# Tasks encountered so far are [3, 4, 0]
# Training tasks iterations so far are [0, 2]

# %%
all_configurations = [
    {'controller': 'BBB' , 'detector_c': 1.7, 'detector_m': 200, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.7, 'detector_m': 50, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.5, 'detector_m': 100, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.2, 'detector_m': 200, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.2, 'detector_m': 50, 'number_demonstrations': 10},
]

summarize_mujoco_runs(domain_name='HalfCheetah', all_configurations=all_configurations, simulation_iterators=[0,1,2,3,4])
# Out:
# Configuration is BBB, detector_c is 1.7, detector_m is 200, #demonstrations are 10
# Simulation iteration is 0
# Adaptive thresholds are [0.17784391]
# Tasks trained on already are [7]
# Tasks encountered so far are [7, 8, 1, 5, 3, 4, 2, 0, 9, 6]
# Training tasks iterations so far are [0]
#
# Simulation iteration is 1
# Adaptive thresholds are [0.19015513, 0.18113881]
# Tasks trained on already are [2, 6]
# Tasks encountered so far are [2, 9, 6, 0, 4, 5, 7, 3, 8, 1]
# Training tasks iterations so far are [0, 2]
#
# Simulation iteration is 2
# Adaptive thresholds are [0.17426725, 0.1599949]
# Tasks trained on already are [5, 0]
# Tasks encountered so far are [5, 1, 0, 4, 7, 3, 6, 8, 9, 2]
# Training tasks iterations so far are [0, 2]
#
# Simulation iteration is 3
# Adaptive thresholds are [0.10451663, 0.19051778]
# Tasks trained on already are [1, 6]
# Tasks encountered so far are [1, 3, 6, 5, 2, 7, 8, 0, 9, 4]
# Training tasks iterations so far are [0, 2]
#
# Simulation iteration is 4
# Adaptive thresholds are [0.07517037, 0.18153837, 0.17674488]
# Tasks trained on already are [9, 6, 8]
# Tasks encountered so far are [9, 6, 1, 0, 8, 4, 7, 3, 2, 5]
# Training tasks iterations so far are [0, 1, 4]
#
#
#
# Configuration is BBB, detector_c is 1.7, detector_m is 50, #demonstrations are 10
# Simulation iteration is 0
# Adaptive thresholds are [0.19014384]
# Tasks trained on already are [7]
# Tasks encountered so far are [7, 8, 1, 5, 3, 4, 2, 0, 9, 6]
# Training tasks iterations so far are [0]
#
# Simulation iteration is 1
# Adaptive thresholds are [0.7437092, 0.69256234]
# Tasks trained on already are [2, 6]
# Tasks encountered so far are [2, 9, 6, 0, 4, 5, 7, 3, 8, 1]
# Training tasks iterations so far are [0, 2]
#
# Simulation iteration is 2
# Adaptive thresholds are [0.1825654, 0.14119098, 0.14622152]
# Tasks trained on already are [5, 1, 7]
# Tasks encountered so far are [5, 1, 0, 4, 7, 3, 6, 8, 9, 2]
# Training tasks iterations so far are [0, 1, 4]
#
# Simulation iteration is 3
# Adaptive thresholds are [0.10570774, 0.18275045]
# Tasks trained on already are [1, 6]
# Tasks encountered so far are [1, 3, 6, 5, 2, 7, 8, 0, 9, 4]
# Training tasks iterations so far are [0, 2]
#
# Simulation iteration is 4
# Adaptive thresholds are [0.073869035, 0.18584046]
# Tasks trained on already are [9, 6]
# Tasks encountered so far are [9, 6, 1, 0, 8, 4, 7, 3, 2, 5]
# Training tasks iterations so far are [0, 1]
#
#
#
# Configuration is BBB, detector_c is 1.5, detector_m is 100, #demonstrations are 10
# Simulation iteration is 0
# Adaptive thresholds are [0.19923832, 0.15513945, 0.13484721, 0.13641936, 0.3193836]
# Tasks trained on already are [7, 8, 1, 0, 6]
# Tasks encountered so far are [7, 8, 1, 5, 3, 4, 2, 0, 9, 6]
# Training tasks iterations so far are [0, 1, 2, 7, 9]
#
# Simulation iteration is 1
# Adaptive thresholds are [0.19080359, 0.15942478, 0.53981316, 0.14209025, 0.3059541]
# Tasks trained on already are [2, 9, 6, 7, 8]
# Tasks encountered so far are [2, 9, 6, 0, 4, 5, 7, 3, 8, 1]
# Training tasks iterations so far are [0, 1, 2, 6, 8]
#
# Simulation iteration is 2
# Adaptive thresholds are [0.17375867, 0.15702207, 0.12874842]
# Tasks trained on already are [5, 1, 3]
# Tasks encountered so far are [5, 1, 0, 4, 7, 3, 6, 8, 9, 2]
# Training tasks iterations so far are [0, 1, 5]
#
# Simulation iteration is 3
# Adaptive thresholds are [0.105214074, 0.13783427, 0.2549456, 0.24483263]
# Tasks trained on already are [1, 3, 6, 7]
# Tasks encountered so far are [1, 3, 6, 5, 2, 7, 8, 0, 9, 4]
# Training tasks iterations so far are [0, 1, 2, 5]
#
# Simulation iteration is 4
# Adaptive thresholds are [0.073187746, 0.54058903]
# Tasks trained on already are [9, 6]
# Tasks encountered so far are [9, 6, 1, 0, 8, 4, 7, 3, 2, 5]
# Training tasks iterations so far are [0, 1]
#
#
#
# Configuration is BBB, detector_c is 1.2, detector_m is 200, #demonstrations are 10
# Simulation iteration is 0
# Adaptive thresholds are [0.20264328, 0.16532364, 0.14323795, 0.12619725, 0.12278483]
# Tasks trained on already are [7, 8, 1, 4, 9]
# Tasks encountered so far are [7, 8, 1, 5, 3, 4, 2, 0, 9, 6]
# Training tasks iterations so far are [0, 1, 2, 5, 8]
#
# Simulation iteration is 1
# Adaptive thresholds are [0.21949796, 0.20565507]
# Tasks trained on already are [6, 8]
# Tasks encountered so far are [6, 8]
# Training tasks iterations so far are [0, 1]
#
# Simulation iteration is 2
# Adaptive thresholds are [0.1809941, 0.36860856]
# Tasks trained on already are [5, 1]
# Tasks encountered so far are [5, 1, 0, 4, 7, 3, 6, 8, 9, 2]
# Training tasks iterations so far are [0, 1]
#
# Simulation iteration is 3
# Adaptive thresholds are [0.104613364, 0.14525731, 0.47688776]
# Tasks trained on already are [1, 3, 6]
# Tasks encountered so far are [1, 3, 6, 5, 2, 7, 8, 0, 9, 4]
# Training tasks iterations so far are [0, 1, 2]
#
# Simulation iteration is 4
# Adaptive thresholds are [0.07249608, 0.1828851, 0.1626534]
# Tasks trained on already are [9, 6, 0]
# Tasks encountered so far are [9, 6, 1, 0, 8, 4, 7, 3, 2, 5]
# Training tasks iterations so far are [0, 1, 3]
#
#
#
# Configuration is BBB, detector_c is 1.2, detector_m is 50, #demonstrations are 10
# Simulation iteration is 0
# Adaptive thresholds are [0.18897207, 0.15715194, 0.14838374, 0.12737086, 0.14693706]
# Tasks trained on already are [7, 8, 3, 0, 9]
# Tasks encountered so far are [7, 8, 1, 5, 3, 4, 2, 0, 9, 6]
# Training tasks iterations so far are [0, 1, 4, 7, 8]
#
# Simulation iteration is 1
# Adaptive thresholds are [0.18626164, 0.15980788, 0.17093018, 0.17159933, 0.16754279, 0.1649664]
# Tasks trained on already are [2, 9, 6, 0, 7, 8]
# Tasks encountered so far are [2, 9, 6, 0, 4, 5, 7, 3, 8, 1]
# Training tasks iterations so far are [0, 1, 2, 3, 6, 8]
#
# Simulation iteration is 2
# Adaptive thresholds are [0.18247278, 0.14802903, 0.20570841]
# Tasks trained on already are [5, 1, 0]
# Tasks encountered so far are [5, 1, 0, 4, 7, 3, 6, 8, 9, 2]
# Training tasks iterations so far are [0, 1, 2]
#
# Simulation iteration is 3
# Adaptive thresholds are [0.10522701, 0.080032356, 0.18059207, 0.32890195]
# Tasks trained on already are [1, 3, 6, 7]
# Tasks encountered so far are [1, 3, 6, 5, 2, 7, 8, 0, 9, 4]
# Training tasks iterations so far are [0, 1, 2, 5]
#
# Simulation iteration is 4
# Adaptive thresholds are [0.077849075, 0.18554041, 0.18073234, 0.17359433, 0.18944605]
# Tasks trained on already are [9, 6, 0, 7, 5]
# Tasks encountered so far are [9, 6, 1, 0, 8, 4, 7, 3, 2, 5]
# Training tasks iterations so far are [0, 1, 3, 6, 9]

# %%
all_configurations = [
    {'controller': 'BBB' , 'detector_c': 1.7, 'detector_m': 200, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.7, 'detector_m': 50, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.5, 'detector_m': 100, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.2, 'detector_m': 200, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.2, 'detector_m': 50, 'number_demonstrations': 10},
]

summarize_mujoco_runs(domain_name='Swimmer', all_configurations=all_configurations, simulation_iterators=[0,1,2,3,4])
# Out:
# Configuration is BBB, detector_c is 1.7, detector_m is 200, #demonstrations are 10
# Simulation iteration is 0
# Adaptive thresholds are [0.1565111, 0.11392078, 0.1394285, 0.14203447, 0.08267831, 0.33774513]
# Tasks trained on already are [7, 8, 1, 3, 4, 2]
# Tasks encountered so far are [7, 8, 1, 5, 3, 4, 2, 0, 9, 6]
# Training tasks iterations so far are [0, 1, 2, 4, 5, 6]
#
# Simulation iteration is 1
# Adaptive thresholds are [0.170979, 0.12845999, 0.10646392, 0.25351968, 0.11107104]
# Tasks trained on already are [2, 9, 6, 0, 1]
# Tasks encountered so far are [2, 9, 6, 0, 4, 5, 7, 3, 8, 1]
# Training tasks iterations so far are [0, 1, 2, 3, 9]
#
# Simulation iteration is 2
# Adaptive thresholds are [0.1455557, 0.50306654, 0.10448696, 0.0887536, 0.13343698, 0.33478895]
# Tasks trained on already are [5, 1, 4, 3, 6, 2]
# Tasks encountered so far are [5, 1, 0, 4, 7, 3, 6, 8, 9, 2]
# Training tasks iterations so far are [0, 1, 3, 5, 6, 9]
#
# Simulation iteration is 3
# Adaptive thresholds are [0.21930142, 0.16553268, 0.1301941, 0.22303091]
# Tasks trained on already are [1, 3, 6, 2]
# Tasks encountered so far are [1, 3, 6, 5, 2, 7, 8, 0, 9, 4]
# Training tasks iterations so far are [0, 1, 2, 4]
#
# Simulation iteration is 4
# Adaptive thresholds are [0.10264821, 0.116458185, 0.105039865, 0.122242294, 0.087190986, 0.19910899]
# Tasks trained on already are [9, 6, 1, 7, 3, 2]
# Tasks encountered so far are [9, 6, 1, 0, 8, 4, 7, 3, 2, 5]
# Training tasks iterations so far are [0, 1, 2, 6, 7, 8]
#
#
#
# Configuration is BBB, detector_c is 1.7, detector_m is 50, #demonstrations are 10
# Simulation iteration is 0
# Adaptive thresholds are [0.15826571, 0.11844315, 0.12826334, 0.103568286, 0.21668695]
# Tasks trained on already are [7, 8, 1, 5, 3]
# Tasks encountered so far are [7, 8, 1, 5, 3, 4, 2, 0, 9, 6]
# Training tasks iterations so far are [0, 1, 2, 3, 4]
#
# Simulation iteration is 1
# Adaptive thresholds are [0.17194131, 0.13818441, 0.106082745, 0.23007098, 0.22148407]
# Tasks trained on already are [2, 9, 6, 0, 1]
# Tasks encountered so far are [2, 9, 6, 0, 4, 5, 7, 3, 8, 1]
# Training tasks iterations so far are [0, 1, 2, 3, 9]
#
# Simulation iteration is 2
# Adaptive thresholds are [0.1396017, 0.14614604, 0.50591695, 0.3524414]
# Tasks trained on already are [5, 1, 4, 7]
# Tasks encountered so far are [5, 1, 0, 4, 7, 3, 6, 8, 9, 2]
# Training tasks iterations so far are [0, 1, 3, 4]
#
# Simulation iteration is 3
# Adaptive thresholds are [0.18808542, 0.16053623, 0.12539653, 0.18023452, 0.2274485]
# Tasks trained on already are [1, 3, 6, 2, 7]
# Tasks encountered so far are [1, 3, 6, 5, 2, 7, 8, 0, 9, 4]
# Training tasks iterations so far are [0, 1, 2, 4, 5]
#
# Simulation iteration is 4
# Adaptive thresholds are [0.2762726, 0.1179935, 0.13429183, 0.11219226, 0.09538025, 0.098963946, 0.18137965]
# Tasks trained on already are [9, 6, 1, 7, 3, 2, 5]
# Tasks encountered so far are [9, 6, 1, 0, 8, 4, 7, 3, 2, 5]
# Training tasks iterations so far are [0, 1, 2, 6, 7, 8, 9]
#
#
#
# Configuration is BBB, detector_c is 1.5, detector_m is 100, #demonstrations are 10
# Simulation iteration is 0
# Adaptive thresholds are [0.14188178, 0.26219025, 0.11623333, 0.111316696, 0.19316903]
# Tasks trained on already are [7, 8, 1, 3, 4]
# Tasks encountered so far are [7, 8, 1, 5, 3, 4, 2, 0, 9, 6]
# Training tasks iterations so far are [0, 1, 2, 4, 5]
#
# Simulation iteration is 1
# Adaptive thresholds are [0.16415, 0.13390577, 0.110677004, 0.09161539, 0.10569658, 0.1613877, 0.17771685]
# Tasks trained on already are [2, 9, 6, 5, 3, 8, 1]
# Tasks encountered so far are [2, 9, 6, 0, 4, 5, 7, 3, 8, 1]
# Training tasks iterations so far are [0, 1, 2, 5, 7, 8, 9]
#
# Simulation iteration is 2
# Adaptive thresholds are [0.14066635, 0.6631061, 0.15579864, 0.13178778, 0.08326352, 0.11562139, 0.2107878]
# Tasks trained on already are [5, 1, 4, 3, 6, 8, 2]
# Tasks encountered so far are [5, 1, 0, 4, 7, 3, 6, 8, 9, 2]
# Training tasks iterations so far are [0, 1, 3, 5, 6, 7, 9]
#
# Simulation iteration is 3
# Adaptive thresholds are [0.20409296, 0.14649545, 0.10976867, 0.14384627, 0.14624484]
# Tasks trained on already are [1, 3, 6, 2, 9]
# Tasks encountered so far are [1, 3, 6, 5, 2, 7, 8, 0, 9, 4]
# Training tasks iterations so far are [0, 1, 2, 4, 8]
#
# Simulation iteration is 4
# Adaptive thresholds are [0.08011199, 0.11204915, 0.10257153, 0.11840063, 0.11695535, 0.25279716]
# Tasks trained on already are [9, 6, 1, 7, 3, 2]
# Tasks encountered so far are [9, 6, 1, 0, 8, 4, 7, 3, 2, 5]
# Training tasks iterations so far are [0, 1, 2, 6, 7, 8]
#
#
#
# Configuration is BBB, detector_c is 1.2, detector_m is 200, #demonstrations are 10
# Simulation iteration is 0
# Adaptive thresholds are [0.15440348, 1.1450512]
# Tasks trained on already are [7, 8]
# Tasks encountered so far are [7, 8, 1, 5, 3, 4, 2, 0, 9, 6]
# Training tasks iterations so far are [0, 1]
#
# Simulation iteration is 1
# Adaptive thresholds are [0.17431347, 0.13468738, 0.1070007, 0.097696714, 0.13789675, 0.29850206, 0.24062839]
# Tasks trained on already are [2, 9, 6, 5, 7, 3, 1]
# Tasks encountered so far are [2, 9, 6, 0, 4, 5, 7, 3, 8, 1]
# Training tasks iterations so far are [0, 1, 2, 5, 6, 7, 9]
#
# Simulation iteration is 2
# Adaptive thresholds are [0.13934255, 0.13481042, 0.14189945, 0.20655641, 0.13132851, 0.098358795]
# Tasks trained on already are [5, 1, 4, 3, 6, 2]
# Tasks encountered so far are [5, 1, 0, 4, 7, 3, 6, 8, 9, 2]
# Training tasks iterations so far are [0, 1, 3, 5, 6, 9]
#
# Simulation iteration is 3
# Adaptive thresholds are [0.19948025, 0.13827968, 0.09652889, 0.09191171, 0.2644444]
# Tasks trained on already are [1, 3, 6, 2, 7]
# Tasks encountered so far are [1, 3, 6, 5, 2, 7, 8, 0, 9, 4]
# Training tasks iterations so far are [0, 1, 2, 4, 5]
#
# Simulation iteration is 4
# Adaptive thresholds are [0.1277002, 0.11406725, 0.32241532, 0.09932233, 0.20759664, 0.10294097, 0.09198177]
# Tasks trained on already are [9, 6, 1, 0, 8, 3, 2]
# Tasks encountered so far are [9, 6, 1, 0, 8, 4, 7, 3, 2, 5]
# Training tasks iterations so far are [0, 1, 2, 3, 4, 7, 8]
#
#
#
# Configuration is BBB, detector_c is 1.2, detector_m is 50, #demonstrations are 10
# Simulation iteration is 0
# Adaptive thresholds are [0.13758041, 0.11930935, 0.15556714, 0.12519066, 0.13978751, 0.21710339, 0.124000214]
# Tasks trained on already are [7, 8, 1, 3, 4, 2, 6]
# Tasks encountered so far are [7, 8, 1, 5, 3, 4, 2, 0, 9, 6]
# Training tasks iterations so far are [0, 1, 2, 4, 5, 6, 9]
#
# Simulation iteration is 1
# Adaptive thresholds are [0.17478806, 0.12891546, 0.105684705, 0.25016385, 0.20297052, 0.117781885]
# Tasks trained on already are [2, 9, 6, 0, 3, 1]
# Tasks encountered so far are [2, 9, 6, 0, 4, 5, 7, 3, 8, 1]
# Training tasks iterations so far are [0, 1, 2, 3, 7, 9]
#
# Simulation iteration is 2
# Adaptive thresholds are [0.13073389, 1.1917808]
# Tasks trained on already are [5, 1]
# Tasks encountered so far are [5, 1, 0, 4, 7, 3, 6, 8, 9, 2]
# Training tasks iterations so far are [0, 1]
#
# Simulation iteration is 3
# Adaptive thresholds are [0.23544717, 0.12013912, 0.124934696, 0.21549731, 0.08072673, 0.1473645]
# Tasks trained on already are [1, 3, 6, 2, 9, 4]
# Tasks encountered so far are [1, 3, 6, 5, 2, 7, 8, 0, 9, 4]
# Training tasks iterations so far are [0, 1, 2, 4, 8, 9]
#
# Simulation iteration is 4
# Adaptive thresholds are [0.38153106, 0.12474062, 0.10705633, 0.17102435, 0.16930933, 0.20632696]
# Tasks trained on already are [9, 6, 1, 8, 3, 2]
# Tasks encountered so far are [9, 6, 1, 0, 8, 4, 7, 3, 2, 5]
# Training tasks iterations so far are [0, 1, 2, 4, 7, 8]

# %%
plt.rcParams["figure.figsize"] = (11,5)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('axes', labelsize=18)

all_configurations = [
    {'controller': 'BBB' , 'detector_c': 1.7, 'detector_m': 200, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.7, 'detector_m': 50, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.5, 'detector_m': 100, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.2, 'detector_m': 200, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.2, 'detector_m': 50, 'number_demonstrations': 10},
    {'controller': 'NAIVE', 'number_demonstrations': 10},
    {'controller': 'RANDOM'},
]

compare_conservativeness_with_scatter_plot(domain_name='HalfCheetah',
                         all_configurations=all_configurations, ymax=49000.,
                         simulation_iterators=[0,1,2,3,4])

# %%
plt.rcParams["figure.figsize"] = (11,5)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('axes', labelsize=18)

all_configurations = [
    {'controller': 'BBB' , 'detector_c': 1.7, 'detector_m': 200, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.7, 'detector_m': 50, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.5, 'detector_m': 100, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.2, 'detector_m': 200, 'number_demonstrations': 10},
    {'controller': 'BBB' , 'detector_c': 1.2, 'detector_m': 50, 'number_demonstrations': 10},
    {'controller': 'NAIVE', 'number_demonstrations': 10},
    {'controller': 'RANDOM'},
]

compare_conservativeness_with_scatter_plot(domain_name='Swimmer',
                         all_configurations=all_configurations, ymax=3500.,
                         simulation_iterators=[0,1,2,3,4])

# %%
plt.rcParams["figure.figsize"] = (10,5)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('axes', labelsize=18)

BBBvsGP_generalization(domain_name='Swimmer', number_demonstrations='1', window_size='1', behavioral_controller='4')
